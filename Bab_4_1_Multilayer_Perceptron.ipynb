# %% [markdown]
# <a href="https://colab.research.google.com/github/HendricoYehezky/Tugas-1/blob/main/Bab_4_1_Multilayer_Perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import torch
from d2l import torch as d2l
import torch

# %%
x = torch.arange(-8.0, 8.0, 0.1, requires_grad=True)
y = torch.relu(x)
d2l.plot(x.detach(), y.detach(), 'x', 'relu(x)', figsize=(5, 2.5))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     245         jpg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'jpg', **kwargs))
#     246     if 'svg' in formats:
# --> 247         svg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'svg', **kwargs))
#     248     if 'pdf' in formats:
#     249         pdf_formatter.for_type(Figure, lambda fig: print_figure(fig, 'pdf', **kwargs))
#
# ...

# %%
y.backward(torch.ones_like(x), retain_graph=True)
d2l.plot(x.detach(), x.grad, 'x', 'grad of relu', figsize=(5, 2.5))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     245         jpg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'jpg', **kwargs))
#     246     if 'svg' in formats:
# --> 247         svg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'svg', **kwargs))
#     248     if 'pdf' in formats:
#     249         pdf_formatter.for_type(Figure, lambda fig: print_figure(fig, 'pdf', **kwargs))
#
# ...

# %%
### Fungsi Sigmoid ###
y = torch.sigmoid(x)
d2l.plot(x.detach(), y.detach(), 'x', 'sigmoid(x)', figsize=(5, 2.5))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     245         jpg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'jpg', **kwargs))
#     246     if 'svg' in formats:
# --> 247         svg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'svg', **kwargs))
#     248     if 'pdf' in formats:
#     249         pdf_formatter.for_type(Figure, lambda fig: print_figure(fig, 'pdf', **kwargs))
#
# ...

# %%
# Clear out previous gradients
x.grad.data.zero_()
y.backward(torch.ones_like(x),retain_graph=True)
d2l.plot(x.detach(), x.grad, 'x', 'grad of sigmoid', figsize=(5, 2.5))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     245         jpg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'jpg', **kwargs))
#     246     if 'svg' in formats:
# --> 247         svg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'svg', **kwargs))
#     248     if 'pdf' in formats:
#     249         pdf_formatter.for_type(Figure, lambda fig: print_figure(fig, 'pdf', **kwargs))
#
# ...

# %%
### Fungsi TanH ###
y = torch.tanh(x)
d2l.plot(x.detach(), y.detach(), 'x', 'tanh(x)', figsize=(5, 2.5))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     245         jpg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'jpg', **kwargs))
#     246     if 'svg' in formats:
# --> 247         svg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'svg', **kwargs))
#     248     if 'pdf' in formats:
#     249         pdf_formatter.for_type(Figure, lambda fig: print_figure(fig, 'pdf', **kwargs))
#
# ...

# %%
# Clear out previous gradients.
x.grad.data.zero_()
y.backward(torch.ones_like(x),retain_graph=True)
d2l.plot(x.detach(), x.grad, 'x', 'grad of tanh', figsize=(5, 2.5))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     245         jpg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'jpg', **kwargs))
#     246     if 'svg' in formats:
# --> 247         svg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'svg', **kwargs))
#     248     if 'pdf' in formats:
#     249         pdf_formatter.for_type(Figure, lambda fig: print_figure(fig, 'pdf', **kwargs))
#
# ...
